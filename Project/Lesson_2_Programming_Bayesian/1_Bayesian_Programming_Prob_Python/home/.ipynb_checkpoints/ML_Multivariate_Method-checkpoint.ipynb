# %%
import numpy as np

# %%
pop_mean = [13, 5]
pop_mean
# Out:
# [13, 5]

# %%
pop_cov = [[5,.3], [.3,2]]
pop_cov
# Out:
# [[5, 0.3], [0.3, 2]]

# %%
mySample = []
mySample = np.random.multivariate_normal(pop_mean, pop_cov, 100)
mySample
# Out:
# array([[15.89255987,  5.13520365],
#        [13.66589349,  6.28405361],
#        [14.86449428,  2.46039387],
#        [14.27420879,  4.1196917 ],
#        [17.48087003,  8.06777596],
#        [14.88384686,  5.12734337],
#        [14.26346277,  7.71970676],
#        [14.15306617,  4.58825111],
#        [14.74898923,  5.87816351],
#        [13.93852504,  7.12408095],
#        [13.21288389,  5.50036997],
#        [13.32065784,  8.12202125],
#        [15.17656957,  4.53942381],
#        [13.13220293,  5.77390546],
#        [ 8.94983013,  3.52291611],
#        [13.45647452,  5.44617535],
#        [12.12232475,  5.13303439],
#        [14.82759169,  4.44642426],
#        [12.07042886,  4.48773995],
#        [15.90946147,  6.72896751],
#        [12.80322706,  3.90946952],
#        [10.69901903,  4.70923696],
#        [13.59605905,  6.13567032],
#        [ 7.66112486,  3.43788628],
#        [11.86969266,  5.01770518],
#        [12.3898279 ,  6.67597472],
#        [12.91137482,  4.62840677],
# ...
